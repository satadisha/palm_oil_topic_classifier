# %%
import numpy as np
np.random.seed(10)
import pandas as pd
from datasets import load_dataset, DatasetDict, Dataset
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#shared drive version at everyone can set up
df = pd.read_csv('/content/gdrive/MyDrive/Group 3: palm oil topic classifier/Data/NEW_palm_oil_grievance_logs.csv')
df.drop_duplicates()
# Out:
#       pk   source internal_id                       status submitted_on  \
# 0    431  Cargill       DSP-1     Closed - With Monitoring      2020-07
# 1    432  Cargill       DSP-2  In Progress - Investigation      2022-02
# 2    433  Cargill       DSP-3     Closed - With Monitoring      2022-04
# 3    434  Cargill       DSP-4                  In Progress      2019-06
# 4    435  Cargill       DSP-5  In Progress - Investigation     5/8/2019
# ..   ...      ...         ...                          ...          ...
# 165  596  Reckitt       220.2  In Progress - Investigation     1/5/2023
# 166  597  Reckitt       207.9  In Progress - Investigation     1/5/2023
# 167  598  Reckitt       238.1                    Submitted    9/13/2022
# 168  599  Reckitt       254.1  In Progress - Investigation    12/6/2023
# 169  600  Reckitt       255.1  In Progress - Investigation    6/22/2023
#
#      accepted_on last_updated_on    country           region  \
# ...

# %%
formatted_df = df[['pk','summary']]
formatted_df
# Out:
#       pk                                            summary
# 0    431  In July 2020, Cargill received a grievance aga...
# 1    432  A grievance was filed against Agropalma regard...
# 2    433  This grievance was filed by Friends of the Ear...
# 3    434  A grievance was filed against Brasil Bio Fuels...
# 4    435  A grievance was filed by Link-Ar Borneo agains...
# ..   ...                                                ...
# 165  596  A grievance has been filed against PT ASM rega...
# 166  597  The grievance concerns PT SIL & SIP (Sebakis I...
# 167  598  The grievance involves a report by Rainforest ...
# 168  599  This grievance concerns the deforestation of T...
# 169  600  Mighty Earth's Rapid Response Report 42 report...
#
# [170 rows x 2 columns]

# %%
# Convert to CSV and save
formatted_df.to_csv("NEW_grievances_formatted.csv",index = False)
from google.colab import files
# files.download("NEW_grievances_formatted.csv")

# %% [markdown]
# # 80/20 Train/Val

# %%
from sklearn.model_selection import train_test_split
df = pd.read_csv('/content/gdrive/MyDrive/Group 3: palm oil topic classifier/Data/combined_shuffled.csv') # Already loaded in df

# %%
# Train (80%) and val Split (20%)
train, val = train_test_split(df, test_size=0.2, random_state=10)

# Convert to TRAIN to CSV and save
train.to_csv("combined_BERT.csv",index = False)
from google.colab import files
files.download("combined_BERT.csv")

# Convert to VAL CSV and save
val.to_csv("combined_testing.csv",index = False)
from google.colab import files
files.download("combined_testing.csv")

print(f"Train size: {len(train)}")
print(f"Val size: {len(val)}")

# New Test Data
# Out:
# Train size: 480
# Val size: 120

# %%
train.groupby('manual_label').count()
# Out:
#               summary
# manual_label
# 0                  20
# 1                  31
# 2                  11
# 3                  47
# 4                  18
# 5                   9
